# %% [markdown]
# # Logical and Arithmetical Operations on Images - Tasks
#
# _Mikołaj Leszczuk, Andrzej Matiolański, Zbigniew Hulicki_
#
# ![](https://i.creativecommons.org/l/by/4.0/88x31.png)

# %% [markdown]
# ## Logical Operations

# %% [markdown]
# ### Thresholding

# %% [markdown]
# Thresholding produces a binary image from a grey-scale or color image by setting pixel values to 1 or 0 depending on whether they are above or below the threshold value.
#
# Thresholding is commonly used to separate or segment a region
# or object within the image based upon its pixel values.

# %% [markdown]
# ![](thresholding_example.png)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
# !wget -O bear.jpg https://media.krakow.travel/photos/45306/noresize.jpg
# Out:
# --2025-11-12 23:42:05--  https://media.krakow.travel/photos/45306/noresize.jpg
# Resolving media.krakow.travel (media.krakow.travel)... 62.121.130.31
# Connecting to media.krakow.travel (media.krakow.travel)|62.121.130.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4803195 (4.6M) [image/jpeg]
# Saving to: ‘bear.jpg’
#
# bear.jpg            100%[===================>]   4.58M  2.74MB/s    in 1.7s
#
# 2025-11-12 23:42:07 (2.74 MB/s) - ‘bear.jpg’ saved [4803195/4803195]

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('bear.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.show()


th_value = 120
_, binary = cv2.threshold(img, th_value, 255, cv2.THRESH_BINARY)

plt.imshow(binary, cmap='gray')
plt.title(f"Image after thresholding (treshold = {th_value})")
plt.show()

# %% [markdown]
# ## Arithmetic Operations

# %% [markdown]
# Arithmetic operation on images is the implementation of standard arithmetic operation such as: addition, subtraction, multiplication, division, which are performed pixel by pixel between two images or among many images, or adding a value to each image pixel value which can be used to achieve some effects on image, such as contrast adjustment for example.

# %% [markdown]
# ### Image Addition

# %% [markdown]
# This is also called pixel addition. An addition operator adds two images in pixel by pixel fashion.
#
# As we mentioned above, we can also add a value to an image pixel value.

# %% [markdown]
# #### Image to Constant Value Addition

# %% [markdown]
# Adding a positive constant value to each pixel location increases its value, and the result called “Contrast adjustment”

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('bear.jpg', cv2.IMREAD_GRAYSCALE)

constant_value = 40

bright_img = img + constant_value

bright_img = np.clip(bright_img, 0, 255)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original image")

plt.subplot(1,2,2)
plt.imshow(bright_img, cmap='gray')
plt.title(f"Image after adding +{constant_value}")

plt.show()

# %% [markdown]
# #### Two Images Addition

# %% [markdown]
# ![](two_images_addition.png)

# %% [markdown]
# Comments:
# 1. Generally, images must be of the same dimension and of the same data type (e.g. 8 bit integer) for addition and subtraction to be possible between them.
# 2. Addition operation could be performed on gray scale images and black and white images as well, and to achieve that, RGB images should be converted to gray scale or black and white if they are not originally in gray scale, or B&W.

# %%
# !wget -O stadium.jpg https://d-art.ppstatic.pl/kadry/k/r/1/6d/05/6663e9ff376d9_o_xlarge.jpg
# Out:
# --2025-11-12 23:42:20--  https://d-art.ppstatic.pl/kadry/k/r/1/6d/05/6663e9ff376d9_o_xlarge.jpg
# Resolving d-art.ppstatic.pl (d-art.ppstatic.pl)... 104.18.15.24, 104.18.14.24, 2606:4700::6812:e18, ...
# Connecting to d-art.ppstatic.pl (d-art.ppstatic.pl)|104.18.15.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 192742 (188K) [image/jpeg]
# Saving to: ‘stadium.jpg’
#
# stadium.jpg         100%[===================>] 188.22K  --.-KB/s    in 0.004s
#
# 2025-11-12 23:42:21 (48.1 MB/s) - ‘stadium.jpg’ saved [192742/192742]

# %%
import cv2
import matplotlib.pyplot as plt

img1 = cv2.imread('bear.jpg')
img2 = cv2.imread('stadium.jpg')

img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

img2_gray = cv2.resize(img2_gray, (img1_gray.shape[1], img1_gray.shape[0]))

added_img = cv2.add(img1_gray, img2_gray)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(img1_gray, cmap='gray')
plt.title("Image 1 (Grayscale)")

plt.subplot(1,3,2)
plt.imshow(img2_gray, cmap='gray')
plt.title("Image 2 (Grayscale Resized)")

plt.subplot(1,3,3)
plt.imshow(added_img, cmap='gray')
plt.title("Added Image")

plt.show()
